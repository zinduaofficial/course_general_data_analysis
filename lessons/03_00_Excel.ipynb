# %% [markdown]
# # Introduction to The Course
#
# In this course, you will learn the following:
#
# ---
#
# ## For Part-Time Students
#
# > **Pro Tip**: Watch the videos at 1.5X or 2X speed if you're already familiar with some Excel basics.
#
# ### **Day 1: Introduction to Excel**
# - Tips and Tricks in Excel
# - Navigating within Excel (To Speed Up Your Workflow)
# - Useful Keyboard Shortcuts
# - Using Filters within Excel (You will be dealing with various data)
#
# ### **Day 2: Intermediate Excel**
# - Intermediate Excel Tips and Tricks
# - Introduction to Functions
# - Conditional Formatting
# - Moving and Copying Columns
# - Freeze Panes in Excel
# - Functions and Formulas in Excel
#   - The Syntax
#   - Conditionals & Logical Operators
#   - Basic Statistical Functions
#
# ### **Day 3: Advanced Excel**
# **(More Excel Functions and Excel Pivot Tables)**
# - Functions and Formulas in Excel
#   - Lookup/Reference Functions
#   - Text Formulas
#   - Date & Time Functions
#   - Fixing Common Errors in Excel Functions
# - Pivot Tables
#   - Introduction to Pivot Tables
#   - The Analyze and Design Tabs
#   - Pivot Formatting
#   - Sorting, Filtering & Grouping
#
# ### **Day 4: Data Visualization in Excel**
# **(Continuation of Pivot Tables and Data Viz)**
# - Pivot Tables
# - Slicers
# - Calculated Values and Fields
# - Pivot Charts
# - Data Visualization Best Practices
# - Choosing the Best Visualizations
# - Beginner’s Guide to Excel Dashboards
# - Intermediate Guide to Excel Dashboards
#
# ### **Day 5: Excel Project**
#
# ---
#
# ## For Full-Time Students
#
# > **Pro Tip**: Watch the videos at 1.5X or 2X speed if you're already familiar with some Excel basics.
#
# ### **Day 1: Introduction to Excel**
# - Tips and Tricks in Excel
# - Navigating within Excel (To Speed Up Your Workflow)
# - Useful Keyboard Shortcuts
# - Using Filters within Excel (You will be dealing with various data)
#
# ### **Day 1: Intermediate Excel**
# - Intermediate Excel Tips and Tricks
# - Introduction to Functions
# - Conditional Formatting
# - Moving and Copying Columns
# - Freeze Panes in Excel
# - Functions and Formulas in Excel
#   - The Syntax
#   - Conditionals & Logical Operators
#   - Basic Statistical Functions
#
# ### **Day 2: Advanced Excel**
# **(More Excel Functions and Excel Pivot Tables)**
# - Functions and Formulas in Excel
#   - Lookup/Reference Functions
#   - Text Formulas
#   - Date & Time Functions
#   - Fixing Common Errors in Excel Functions
# - Pivot Tables
#   - Introduction to Pivot Tables
#   - The Analyze and Design Tabs
#   - Pivot Formatting
#   - Sorting, Filtering & Grouping
#
# ### **Day 3 (Part 1): Data Visualization in Excel**
# **(Continuation of Pivot Tables and Data Viz)**
# - Pivot Tables
# - Slicers
# - Calculated Values and Fields
# - Pivot Charts
# - Data Visualization Best Practices
# - Choosing the Best Visualizations
# - Beginner’s Guide to Excel Dashboards
# - Intermediate Guide to Excel Dashboards
#
# ### **Day 3 (Part 2): Excel Project**
